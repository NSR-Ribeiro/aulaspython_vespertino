# %%
import pandas as pd
df = pd.read_csv('dataset2/pesquisa2.csv')
df
# Out:
#    Carimbo de data/hora  Avalie os estilos musicais [rock]  \
# 0   21/08/2024 10:03:25                                  3
# 1   21/08/2024 10:04:39                                  5
# 2   21/08/2024 10:04:52                                  1
# 3   21/08/2024 10:04:53                                  1
# 4   21/08/2024 10:04:55                                  5
# ..                  ...                                ...
# 90  22/08/2024 10:31:40                                  3
# 91  22/08/2024 10:31:45                                  1
# 92  22/08/2024 10:38:10                                  1
# 93  22/08/2024 10:39:06                                  5
# 94  22/08/2024 10:40:15                                  5
#
#     Avalie os estilos musicais [hip hop]  Avalie os estilos musicais [mpb]  \
# 0                                      1                                 1
# 1                                      3                                 5
# ...

# %%
df_luciano = df[df['Qual professor'] == 'Luciano']
df_luciano
# Out:
#    Carimbo de data/hora  Avalie os estilos musicais [rock]  \
# 66  22/08/2024 09:57:42                                  1
# 67  22/08/2024 09:58:20                                  1
# 68  22/08/2024 09:58:49                                  4
# 69  22/08/2024 09:59:53                                  3
# 70  22/08/2024 10:00:24                                  5
# 71  22/08/2024 10:00:25                                  1
# 72  22/08/2024 10:00:35                                  2
# 73  22/08/2024 10:01:00                                  2
# 74  22/08/2024 10:01:35                                  3
# 75  22/08/2024 10:01:41                                  1
# 76  22/08/2024 10:02:12                                  5
# 94  22/08/2024 10:40:15                                  5
#
#     Avalie os estilos musicais [hip hop]  Avalie os estilos musicais [mpb]  \
# 66                                     2                                 3
# ...

# %%
import seaborn as sns

# %%
import matplotlib.pyplot as plt

# %%
import numpy as np

# %%
data = {
    'Estilo Musical': ['Rock', 'Hip Hop', 'MPB', 'Reggae', 'Funk', 'Sertanejo', 'Gospel', 'Eletrônica'],
    'Nota': [5, 2, 1, 3, 1, 2, 1, 5]
}
df_luciano = pd.DataFrame(data)

fig, ax = plt.subplots(figsize=(12, 8))

colors = plt.cm.viridis(np.linspace(0, 1, len(df_luciano)))
bars = ax.barh(df_luciano['Estilo Musical'], df_luciano['Nota'], color=colors)

ax.set_title('Avaliação dos Estilos Musicais - Luciano', fontsize=16)
ax.set_xlabel('Nota', fontsize=14)
ax.set_ylabel('Estilo Musical', fontsize=14)

for bar in bars:
    width = bar.get_width()
    ax.text(width, bar.get_y() + bar.get_height()/2, f'{width}', va='center', ha='left', fontsize=12, color='black')

plt.tight_layout()
plt.show()
