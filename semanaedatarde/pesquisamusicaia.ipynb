# %% [markdown]
# # Pesquisa para criar música por IA (suno)

# %% [markdown]
# ## Pesquisa de campo
#
# - Utilzando formulário
# - Amostra (turma do ensino médio - curso de redes)
# - Disponibilização de QRcode para acessar formulário

# %% [markdown]
# Grupo 3 - Jessica (meu grupo NSR)
# Grupo 4
#
# - Sala professor
# - Apagar a coluna de data e hora
# - Renomear as colunas
# - Criar um gráfico de barras horizontal de todos os estilos.
# - Criar um gráfico de barras horizontal apenas do seu grupo.
# - Escolher as palavras chaves
# - Gerar uma música com as palavras chaves

# %% [markdown]
# # Todas importações necessárias para atividade IA (suno - criação de música)
#
# - importação pandas
# - importação numpy
# - importação seaborn
# - importação matplotlib

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# ## Importando Dataset ([text](dataset/pesquisa_musical_alunos.csv))

# %%
# Importando Dataset (criando variável)

pesquisa_estilo = pd.read_csv('dataset/pesquisa_musical_alunos.csv')

# %% [markdown]
# ## Mostar os dados dentro da variável

# %%
pesquisa_estilo
# Out:
#     Carimbo de data/hora  Avalie os estilos musicais [rock]  \
# 0    21/08/2024 10:03:25                                  3
# 1    21/08/2024 10:04:39                                  5
# 2    21/08/2024 10:04:52                                  1
# 3    21/08/2024 10:04:53                                  1
# 4    21/08/2024 10:04:55                                  5
# ..                   ...                                ...
# 142  22/08/2024 16:47:00                                  3
# 143  22/08/2024 16:48:04                                  1
# 144  22/08/2024 16:51:25                                  4
# 145  22/08/2024 16:52:02                                  4
# 146  22/08/2024 17:00:29                                  4
#
#      Avalie os estilos musicais [rap]  Avalie os estilos musicais [mpb]  \
# 0                                   1                                 1
# 1                                   3                                 5
# ...

# %%
pesquisa_estilo.head()
# Out:
#   Carimbo de data/hora  Avalie os estilos musicais [rock]  \
# 0  21/08/2024 10:03:25                                  3
# 1  21/08/2024 10:04:39                                  5
# 2  21/08/2024 10:04:52                                  1
# 3  21/08/2024 10:04:53                                  1
# 4  21/08/2024 10:04:55                                  5
#
#    Avalie os estilos musicais [rap]  Avalie os estilos musicais [mpb]  \
# 0                                 1                                 1
# 1                                 3                                 5
# 2                                 5                                 1
# 3                                 5                                 4
# 4                                 4                                 3
#
#    Avalie os estilos musicais [reggae]  Avalie os estilos musicais [funk]  \
# 0                                    1                                  1
# ...

# %%
pesquisa_estilo.columns
# Out:
# Index(['Carimbo de data/hora', 'Avalie os estilos musicais [rock]',
#        'Avalie os estilos musicais [rap]', 'Avalie os estilos musicais [mpb]',
#        'Avalie os estilos musicais [reggae]',
#        'Avalie os estilos musicais [funk]',
#        'Avalie os estilos musicais [sertanejo]',
#        'Avalie os estilos musicais [gospel]',
#        'Avalie os estilos musicais [eletrônica]', 'Qual professor',
#        'Qual sua faixa etária', 'Avalie os estilos musicais [samba]',
#        'Avalie os estilos musicais [forró]',
#        'Avalie os estilos musicais [trap]',
#        'Digite uma palavra-chave do seu curso que pode ser incluída na música gerada por inteligência artificial?'],
#       dtype='object')

# %%
['data_hora','email','pontuacao','compreensao','desafiador','sentimento']
# Out:
# ['data_hora', 'email', 'pontuacao', 'compreensao', 'desafiador', 'sentimento']

# %%
pesquisa_estilo.columns
# Out:
# Index(['Carimbo de data/hora', 'Avalie os estilos musicais [rock]',
#        'Avalie os estilos musicais [rap]', 'Avalie os estilos musicais [mpb]',
#        'Avalie os estilos musicais [reggae]',
#        'Avalie os estilos musicais [funk]',
#        'Avalie os estilos musicais [sertanejo]',
#        'Avalie os estilos musicais [gospel]',
#        'Avalie os estilos musicais [eletrônica]', 'Qual professor',
#        'Qual sua faixa etária', 'Avalie os estilos musicais [samba]',
#        'Avalie os estilos musicais [forró]',
#        'Avalie os estilos musicais [trap]',
#        'Digite uma palavra-chave do seu curso que pode ser incluída na música gerada por inteligência artificial?'],
#       dtype='object')
