# %% [markdown]
# # Atividade Pesquisa Musical

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
pesquisa_musical = pd.read_csv('dataset/pesquisa_musical.csv')

# %%
pesquisa_musical.columns = ['data_hora','rock','hiphop','mpb','reggae','funk','sertanejo','gospel','eletronica']

# %%
pesquisa_musical.columns
# Out:
# Index(['data_hora', 'rock', 'hiphop', 'mpb', 'reggae', 'funk', 'sertanejo',
#        'gospel', 'eletronica'],
#       dtype='object')

# %%
pesquisa_musical.head()
# Out:
#              data_hora  rock  hiphop  mpb  reggae  funk  sertanejo  gospel  \
# 0  21/08/2024 10:03:25     3       1    1       1     1          1       1
# 1  21/08/2024 10:04:39     5       3    5       2     1          3       1
# 2  21/08/2024 10:04:52     1       5    1       1     1          1       1
# 3  21/08/2024 10:04:53     1       5    4       4     4          1       1
# 4  21/08/2024 10:04:55     5       4    3       4     1          1       2
#
#    eletronica
# 0           3
# 1           5
# 2           5
# 3           5
# 4           5

# %%
#Remover a coluna 'data-hora' para realizar o cálculo

df_nota = pesquisa_musical.drop(columns=['data_hora'])

# %%
pesquisa_musical.head()
# Out:
#              data_hora  rock  hiphop  mpb  reggae  funk  sertanejo  gospel  \
# 0  21/08/2024 10:03:25     3       1    1       1     1          1       1
# 1  21/08/2024 10:04:39     5       3    5       2     1          3       1
# 2  21/08/2024 10:04:52     1       5    1       1     1          1       1
# 3  21/08/2024 10:04:53     1       5    4       4     4          1       1
# 4  21/08/2024 10:04:55     5       4    3       4     1          1       2
#
#    eletronica
# 0           3
# 1           5
# 2           5
# 3           5
# 4           5

# %%
pesquisa = pd.read_csv('dataset/pesquisa_musical.csv')

# %%
soma = df_nota.sum()
soma
# Out:
# rock          136
# hiphop        119
# mpb           127
# reggae         88
# funk           73
# sertanejo      93
# gospel        100
# eletronica    122
# dtype: int64

# %%
media = df_nota.mean()
media
# Out:
# rock          3.675676
# hiphop        3.216216
# mpb           3.432432
# reggae        2.378378
# funk          1.972973
# sertanejo     2.513514
# gospel        2.702703
# eletronica    3.297297
# dtype: float64

# %%
mediana = df_nota.median()
mediana
# Out:
# rock          4.0
# hiphop        4.0
# mpb           4.0
# reggae        2.0
# funk          1.0
# sertanejo     3.0
# gospel        2.0
# eletronica    4.0
# dtype: float64

# %%
quartis = df_nota.quantile()
quartis
# Out:
# rock          4.0
# hiphop        4.0
# mpb           4.0
# reggae        2.0
# funk          1.0
# sertanejo     3.0
# gospel        2.0
# eletronica    4.0
# Name: 0.5, dtype: float64

# %%
sns.histplot(media,kde=True,bins=15)
# Out:
# <Axes: ylabel='Count'>

# %%
sns.histplot(mediana,kde=True,bins=15)
# Out:
# <Axes: ylabel='Count'>

# %%
import matplotlib.pyplot as plt
plt.hist(media)
plt.title("Pesquisa Musical")
# Out:
# Text(0.5, 1.0, 'Pesquisa Musical')

# %%
 
df = pesquisa['Sent'].value_counts(normalize=True).reset_index()
df.columns = ['Sentimento', 'Porcentagem']

# Criar o gráfico de barras
ax = sns.barplot(x='Sentimento', y='Porcentagem', data=df)

# Adicionar as porcentagens nas barras
ax.bar_label(ax.containers[0], fmt='%.2f%%')

# Mostrar o gráfico
sns.boxplot()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 df = pesquisa['Sent'].value_counts(normalize=True).reset_index()
#       2 df.columns = ['Sentimento', 'Porcentagem']
#       4 # Criar o gráfico de barras
#
# NameError: name 'pesquisa' is not defined

# %%
import seaborn as sns
import matplotlib.pyplot as plt
plt.figure(figsize=(10, 6))
soma.plot(kind='barh', color=['blue'])
# Out:
# <Axes: >

# %%
# Cria um histograma para cada estilo musical
plt.figure(figsize=(14, 12))

for i, column in enumerate(df_nota.columns, 1):
    plt.subplot(3, 3, i)  # Ajusta o layout para vários subgráficos
    sns.histplot(df_nota[column], bins=5, kde=True, color='skyblue')
    plt.title(f'Estilo: {column}')
    plt.xlabel('Nota')
    plt.ylabel('Frequência')

plt.tight_layout()
plt.show()
